# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

# %%
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
from src.baseline_cnn_lstm import BaselineCNNLSTM
import torch

model = mobilenet_v2(weights=MobileNet_V2_Weights.DEFAULT)

x = torch.randn(1, 3, 224, 224)

features = model.features(x)

print(features.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
# ----> 2 from src.baseline_cnn_lstm import BaselineCNNLSTM
#       3 import torch
#       4
#       5 model = mobilenet_v2(weights=MobileNet_V2_Weights.DEFAULT)
#
# ImportError: cannot import name 'BaselineCNNLSTM' from 'src.baseline_cnn_lstm' (/mnt/vurm/homes/homes/mp2940/violence-detection-dissertation/src/baseline_cnn_lstm.py)
